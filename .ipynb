# %%
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
from dotenv import load_dotenv
import os

def upload_folder_to_blob(folder_path, container_name, connection_string, data_layer):
    # Create a BlobServiceClient using the connection string
    blob_service_client = BlobServiceClient.from_connection_string(connection_string)
    
    # Create a ContainerClient
    container_client = blob_service_client.get_container_client(container_name)
    
    # check if container already exists, if not create it
    if not container_client.exists():
        container_client.create_container()

    for r,d,f in os.walk(folder_path):        
        if f:
            for file in f:
                file_path_on_azure = os.path.join(r,file).replace('data',data_layer)
                file_path_on_local = os.path.join(r,file)
                # upload the file to blob
                blob_client = blob_service_client.get_blob_client(container=container_name, blob=file_path_on_azure)
                with open(file_path_on_local, "rb") as data:
                    blob_client.upload_blob(data, overwrite=True)
                    print(f"Uploaded {file_path_on_azure} to Azure Blob Storage")

    print(folder_path)

# %%
dotenv_path = '.env'
load_dotenv(dotenv_path)
connection_string = os.getenv('BLOB_STORAGE_CONNECTION_STRING')

# Example usage
folder_to_upload = "data/EuroSAT_MS"
print(os.path.exists(folder_to_upload))
container_name = "data-container"
data_layer = "bronze_layer"

upload_folder_to_blob(folder_to_upload, container_name, connection_string, data_layer)
# Out:
# True
# Uploaded bronze_layer/EuroSAT_MS\Forest\Forest_10.tif to Azure Blob Storage
# Uploaded bronze_layer/EuroSAT_MS\Forest\Forest_100.tif to Azure Blob Storage
# Uploaded bronze_layer/EuroSAT_MS\Forest\Forest_1000.tif to Azure Blob Storage
# Uploaded bronze_layer/EuroSAT_MS\Forest\Forest_1001.tif to Azure Blob Storage
# Uploaded bronze_layer/EuroSAT_MS\Forest\Forest_1002.tif to Azure Blob Storage
# Uploaded bronze_layer/EuroSAT_MS\Forest\Forest_1003.tif to Azure Blob Storage
# Uploaded bronze_layer/EuroSAT_MS\Forest\Forest_1004.tif to Azure Blob Storage
# Uploaded bronze_layer/EuroSAT_MS\Forest\Forest_1005.tif to Azure Blob Storage
# Uploaded bronze_layer/EuroSAT_MS\Forest\Forest_1006.tif to Azure Blob Storage
# Uploaded bronze_layer/EuroSAT_MS\Forest\Forest_1007.tif to Azure Blob Storage
# Uploaded bronze_layer/EuroSAT_MS\Forest\Forest_1008.tif to Azure Blob Storage
# Uploaded bronze_layer/EuroSAT_MS\Forest\Forest_1009.tif to Azure Blob Storage
# ...
